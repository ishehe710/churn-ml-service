# %% [markdown]
# <h1>EDA</h1>

# %%
# 01_eda.ipynb

import pandas as pd
import sqlite3

# Connect to SQL database
conn = sqlite3.connect("../../sql/telco_churn.db")

# Load table into pandas
df = pd.read_sql("SELECT * FROM customers", conn)
conn.close()

# Quick look at the data
df.head()
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/shehe/AppData/Local/Microsoft/WindowsApps/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'
